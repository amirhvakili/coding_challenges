# %% [markdown]
# # Pandas Practice
#
# This notebook is dedicated to practicing different tasks with pandas. The solutions are available in a solutions notebook, however, you should always try to figure them out yourself first.
#
# It should be noted there may be more than one different way to answer a question or complete an exercise.
#
# Exercises are based off (and directly taken from) the quick introduction to pandas notebook.
#
# Different tasks will be detailed by comments or text.
#
# For further reference and resources, it's advised to check out the [pandas documentation](https://pandas.pydata.org/pandas-docs/stable/).

# %%
# Import pandas
import pandas as pd

# %%
# Create a series of three different colours
colours = pd.Series(["Red", "Blue", "Yellow"])
colours
# Out:
# 0       Red
# 1      Blue
# 2    Yellow
# dtype: object

# %%
# View the series of different colours
colours
# Out:
# 0       Red
# 1      Blue
# 2    Yellow
# dtype: object

# %%
# Create a series of three different car types and view it
cars = pd.Series(["BMW", "Benz", "Toyota"])
cars
# Out:
# 0       BMW
# 1      Benz
# 2    Toyota
# dtype: object

# %%
# Combine the Series of cars and colours into a DataFrame
cars_data = pd.DataFrame({"Car Make": cars, "Colour": colours})
cars_data
# Out:
#   Car Make  Colour
# 0      BMW     Red
# 1     Benz    Blue
# 2   Toyota  Yellow

# %%
# Import "../data/car-sales.csv" and turn it into a DataFrame
car_sales = pd.read_csv("7.1 car-sales.csv.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# **Note:** Since you've imported `../data/car-sales.csv` as a DataFrame, we'll now refer to this DataFrame as 'the car sales DataFrame'.

# %%
# Export the DataFrame you created to a .csv file
car_sales.to_csv("the car sales DataFrame.csv")

# %%
# Find the different datatypes of the car data DataFrame
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
# Describe your current car sales DataFrame using describe()
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
# Get information about your DataFrame using info()
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %% [markdown]
# What does it show you?

# %%
# Create a Series of different numbers and find the mean of them
numbers = pd.Series([10,23,35,26,49,53,221,547,2155,654,56,213,145])
numbers.mean()
# Out:
# 322.0769230769231

# %%
# Create a Series of different numbers and find the sum of them
numbers2 = pd.Series([10,2,5,26,254,266,254,66,997,754,152,366,548,22,10,125,45])
numbers2.sum()
# Out:
# 3902

# %%
# List out all the column names of the car sales DataFrame
for col in car_sales.columns:
    print(col)
# Out:
# Make
# Colour
# Odometer (KM)
# Doors
# Price

# %%
# Find the length of the car sales DataFrame
len(car_sales.index)
# Out:
# 10

# %%
# Show the first 5 rows of the car sales DataFrame
car_sales.head(5)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
# Show the first 7 rows of the car sales DataFrame
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
# Show the bottom 5 rows of the car sales DataFrame
car_sales.tail(5)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# Use .loc to select the row at index 3 of the car sales DataFrame
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# Use .iloc to select the row at position 3 of the car sales DataFrame
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %% [markdown]
# Notice how they're the same? Why do you think this is?
#
# Check the pandas documentation for [.loc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html) and [.iloc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html). Think about a different situation each could be used for and try them out.

# %%
# Select the "Odometer (KM)" column from the car sales DataFrame
car_sales["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
# Find the mean of the "Odometer (KM)" column in the car sales DataFrame
car_sales["Odometer (KM)"].mean()
# Out:
# 78601.4

# %%
# Select the rows with over 100,000 kilometers on the Odometer
car_sales.loc[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
# Create a crosstab of the Make and Doors columns
car_sales_crossed = pd.crosstab(car_sales.Make, car_sales.Doors)
car_sales_crossed
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Group columns of the car sales DataFrame by the Make column and find the average
car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# Import Matplotlib and create a plot of the Odometer column
# Don't forget to use %matplotlib inline
import matplotlib.pyplot as plt
car_sales.plot(x = "Make", y = "Odometer (KM)", kind = "bar")
# Out:
# <AxesSubplot:xlabel='Make'>

# %%
# Create a histogram of the Odometer column using hist()
car_sales.hist(["Odometer (KM)"])
# Out:
# array([[<AxesSubplot:title={'center':'Odometer (KM)'}>]], dtype=object)

# %%
# Try to plot the Price column using plot()
car_sales = pd.read_csv("7.1 car-sales.csv.csv")
car_sales["Price"] = car_sales["Price"].replace('[\$\,\.]', '', regex=True).astype(float)
car_sales
car_sales.plot(x = "Make", y = "Price", kind = "bar")
# Out:
# <AxesSubplot:xlabel='Make'>

# %% [markdown]
# Why didn't it work? Can you think of a solution?
#
# You might want to search for "how to convert a pandas string column to numbers".
#
# And if you're still stuck, check out this [Stack Overflow question and answer on turning a price column into integers](https://stackoverflow.com/questions/44469313/price-column-object-to-int-in-pandas).
#
# See how you can provide the example code there to the problem here.

# %%
# Remove the punctuation from price column
car_sales["Price"].astype(int)
# Out:
# 0     400000
# 1     500000
# 2     700000
# 3    2200000
# 4     350000
# 5     450000
# 6     750000
# 7     700000
# 8     625000
# 9     970000
# Name: Price, dtype: int32

# %%
# Check the changes to the price column
car_sales["Price"]
# Out:
# 0     400000.0
# 1     500000.0
# 2     700000.0
# 3    2200000.0
# 4     350000.0
# 5     450000.0
# 6     750000.0
# 7     700000.0
# 8     625000.0
# 9     970000.0
# Name: Price, dtype: float64

# %%
# Remove the two extra zeros at the end of the price column
car_sales["Price"] = car_sales["Price"]/100
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
# Check the changes to the Price column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
# Change the datatype of the Price column to integers
car_sales["Price"].astype(int)
# Out:
# 0     4000
# 1     5000
# 2     7000
# 3    22000
# 4     3500
# 5     4500
# 6     7500
# 7     7000
# 8     6250
# 9     9700
# Name: Price, dtype: int32

# %%
# Lower the strings of the Make column
car_sales["Make"].str.lower()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   4000.0
# 1   honda    Red          87899      4   5000.0
# 2  toyota   Blue          32549      3   7000.0
# 3     bmw  Black          11179      5  22000.0
# 4  nissan  White         213095      4   3500.0
# 5  toyota  Green          99213      4   4500.0
# 6   honda   Blue          45698      4   7500.0
# 7   honda   Blue          54738      4   7000.0
# 8  toyota  White          60000      4   6250.0
# 9  nissan  White          31600      4   9700.0

# %% [markdown]
# If you check the car sales DataFrame, you'll notice the Make column hasn't been lowered.
#
# How could you make these changes permanent?
#
# Try it out.

# %%
# Make lowering the case of the Make column permanent
car_sales["Make"] = car_sales["Make"].str.lower()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   4000.0
# 1   honda    Red          87899      4   5000.0
# 2  toyota   Blue          32549      3   7000.0
# 3     bmw  Black          11179      5  22000.0
# 4  nissan  White         213095      4   3500.0
# 5  toyota  Green          99213      4   4500.0
# 6   honda   Blue          45698      4   7500.0
# 7   honda   Blue          54738      4   7000.0
# 8  toyota  White          60000      4   6250.0
# 9  nissan  White          31600      4   9700.0

# %%
# Check the car sales DataFrame
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   4000.0
# 1   honda    Red          87899      4   5000.0
# 2  toyota   Blue          32549      3   7000.0
# 3     bmw  Black          11179      5  22000.0
# 4  nissan  White         213095      4   3500.0
# 5  toyota  Green          99213      4   4500.0
# 6   honda   Blue          45698      4   7500.0
# 7   honda   Blue          54738      4   7000.0
# 8  toyota  White          60000      4   6250.0
# 9  nissan  White          31600      4   9700.0

# %% [markdown]
# Notice how the Make column stays lowered after reassigning.
#
# Now let's deal with missing data.

# %%
# Import the car sales DataFrame with missing data ("../data/car-sales-missing-data.csv")

car_sales_missing = pd.read_csv("9.1 car-sales-extended-missing-data.csv.csv")
# Check out the new DataFrame
car_sales_missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %% [markdown]
# Notice the missing values are represented as `NaN` in pandas DataFrames.
#
# Let's try fill them.

# %%
# Fill the Odometer column missing values with the mean of the column inplace
Odometer_mean = car_sales_missing["Odometer (KM)"].mean()
car_sales_missing["Odometer (KM)"].fillna(value = Odometer_mean, inplace = True )

# %%
# View the car sales missing DataFrame and verify the changes
car_sales_missing.head(50)
# Out:
#       Make Colour  Odometer (KM)  Doors    Price
# 0    Honda  White   35431.000000    4.0  15323.0
# 1      BMW   Blue  192714.000000    5.0  19943.0
# 2    Honda  White   84714.000000    4.0  28343.0
# 3   Toyota  White  154365.000000    4.0  13434.0
# 4   Nissan   Blue  181577.000000    3.0  14043.0
# 5    Honda    Red   42652.000000    4.0  23883.0
# 6   Toyota   Blue  163453.000000    4.0   8473.0
# 7    Honda  White  131253.237895    4.0  20306.0
# 8      NaN  White  130538.000000    4.0   9374.0
# 9    Honda   Blue   51029.000000    4.0  26683.0
# 10  Nissan  White  167421.000000    4.0  16259.0
# 11  Nissan  Green   17119.000000    4.0   6160.0
# 12  Nissan  White  102303.000000    4.0  16909.0
# 13     NaN  White  134181.000000    4.0  11121.0
# 14   Honda   Blue  199833.000000    4.0  18946.0
# 15  Toyota   Blue  205592.000000    4.0  16290.0
# 16  Toyota    Red   96742.000000    4.0  34465.0
# 17     BMW  White  194189.000000    5.0  17177.0
# 18  Nissan  White   67991.000000    3.0   9109.0
# 19  Nissan   Blue  215820.000000    4.0   6010.0
# 20  Toyota    NaN  124844.000000    4.0  24130.0
# 21   Honda    NaN   30615.000000    4.0  29653.0
# 22  Toyota  White  148744.000000    4.0  22489.0
# 23   Honda  Green  130075.000000    4.0  21242.0
# 24   Honda   Blue  172718.000000    4.0  14274.0
# 25   Honda   Blue  125819.000000    4.0  15686.0
# 26   Honda  White  180390.000000    4.0  13344.0
# 27   Honda  Green   82783.000000    4.0  10984.0
# 28   Honda  White   56687.000000    4.0   6135.0
# 29  Toyota  White  112004.000000    4.0  13586.0
# 30  Nissan   Blue   34024.000000    4.0  23929.0
# 31  Toyota  White  108569.000000    NaN   6866.0
# 32  Nissan  White  203795.000000    4.0   9330.0
# 33  Nissan  Green  153554.000000    3.0   9780.0
# 34   Honda   Blue   71949.000000    4.0  17516.0
# 35   Honda   Blue  191622.000000    4.0   8738.0
# 36  Nissan   Blue   38186.000000    4.0  23438.0
# 37  Nissan  White  131253.237895    4.0  15131.0
# 38  Nissan   Blue  146430.000000    3.0   9224.0
# 39  Toyota  Green  109868.000000    4.0   6574.0
# 40     NaN  White  177894.000000    4.0   9229.0
# 41  Toyota   Blue  189209.000000    4.0   7100.0
# 42   Honda  Black  200490.000000    4.0   6337.0
# 43  Toyota   Blue  141617.000000    4.0  19085.0
# 44  Toyota   Blue  213893.000000    4.0   5743.0
# 45  Nissan   Blue  231057.000000    4.0   5925.0
# 46  Toyota  White  100938.000000    4.0  25196.0
# 47  Toyota   Blue  243969.000000    NaN  16138.0
# 48  Nissan  White  107096.000000    3.0   6075.0
# 49  Toyota  Black   86333.000000    4.0   9928.0

# %%
# Remove the rest of the missing data inplace
car_sales_missing.dropna(inplace = True)

# %%
# Verify the missing values are removed by viewing the DataFrame
car_sales_missing.head(50)
# Out:
#       Make Colour  Odometer (KM)  Doors    Price
# 0    Honda  White   35431.000000    4.0  15323.0
# 1      BMW   Blue  192714.000000    5.0  19943.0
# 2    Honda  White   84714.000000    4.0  28343.0
# 3   Toyota  White  154365.000000    4.0  13434.0
# 4   Nissan   Blue  181577.000000    3.0  14043.0
# 5    Honda    Red   42652.000000    4.0  23883.0
# 6   Toyota   Blue  163453.000000    4.0   8473.0
# 7    Honda  White  131253.237895    4.0  20306.0
# 9    Honda   Blue   51029.000000    4.0  26683.0
# 10  Nissan  White  167421.000000    4.0  16259.0
# 11  Nissan  Green   17119.000000    4.0   6160.0
# 12  Nissan  White  102303.000000    4.0  16909.0
# 14   Honda   Blue  199833.000000    4.0  18946.0
# 15  Toyota   Blue  205592.000000    4.0  16290.0
# 16  Toyota    Red   96742.000000    4.0  34465.0
# 17     BMW  White  194189.000000    5.0  17177.0
# 18  Nissan  White   67991.000000    3.0   9109.0
# 19  Nissan   Blue  215820.000000    4.0   6010.0
# 22  Toyota  White  148744.000000    4.0  22489.0
# 23   Honda  Green  130075.000000    4.0  21242.0
# 24   Honda   Blue  172718.000000    4.0  14274.0
# 25   Honda   Blue  125819.000000    4.0  15686.0
# 26   Honda  White  180390.000000    4.0  13344.0
# 27   Honda  Green   82783.000000    4.0  10984.0
# 28   Honda  White   56687.000000    4.0   6135.0
# 29  Toyota  White  112004.000000    4.0  13586.0
# 30  Nissan   Blue   34024.000000    4.0  23929.0
# 32  Nissan  White  203795.000000    4.0   9330.0
# 33  Nissan  Green  153554.000000    3.0   9780.0
# 34   Honda   Blue   71949.000000    4.0  17516.0
# 35   Honda   Blue  191622.000000    4.0   8738.0
# 36  Nissan   Blue   38186.000000    4.0  23438.0
# 37  Nissan  White  131253.237895    4.0  15131.0
# 38  Nissan   Blue  146430.000000    3.0   9224.0
# 39  Toyota  Green  109868.000000    4.0   6574.0
# 41  Toyota   Blue  189209.000000    4.0   7100.0
# 42   Honda  Black  200490.000000    4.0   6337.0
# 43  Toyota   Blue  141617.000000    4.0  19085.0
# 44  Toyota   Blue  213893.000000    4.0   5743.0
# 45  Nissan   Blue  231057.000000    4.0   5925.0
# 46  Toyota  White  100938.000000    4.0  25196.0
# 48  Nissan  White  107096.000000    3.0   6075.0
# 49  Toyota  Black   86333.000000    4.0   9928.0
# 50  Toyota    Red  184878.000000    4.0   7445.0
# 52  Toyota   Blue   77646.000000    4.0  17422.0
# 53  Toyota   Blue  246817.000000    4.0   8269.0
# 55     BMW  White   79937.000000    5.0  48686.0
# 56   Honda  White   82039.000000    4.0  15662.0
# 57     BMW    Red  162176.000000    5.0  19186.0
# 59  Toyota   Blue  230908.000000    4.0  12883.0

# %% [markdown]
# We'll now start to add columns to our DataFrame.

# %%
# Create a "Seats" column where every row has a value of 5
seats = []
for i in range(815):
    seats.append(5)
car_sales_missing["Seats"] = seats
car_sales_missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats
# 0     Honda  White        35431.0    4.0  15323.0      5
# 1       BMW   Blue       192714.0    5.0  19943.0      5
# 2     Honda  White        84714.0    4.0  28343.0      5
# 3    Toyota  White       154365.0    4.0  13434.0      5
# 4    Nissan   Blue       181577.0    3.0  14043.0      5
# ..      ...    ...            ...    ...      ...    ...
# 994     BMW   Blue       163322.0    3.0  31666.0      5
# 995  Toyota  Black        35820.0    4.0  32042.0      5
# 997  Nissan   Blue        66604.0    4.0  31570.0      5
# 998   Honda  White       215883.0    4.0   4001.0      5
# 999  Toyota   Blue       248360.0    4.0  12732.0      5
#
# [815 rows x 6 columns]

# %%
import random as rn

# %%
# Create a column called "Engine Size" with random values between 1.3 and 4.5
# Remember: If you're doing it from a Python list, the list has to be the same length
# as the DataFrame
engine_size = []
for i in range(815):
    random = rn.uniform(1.3, 4.5)
    engine_size.append(random)
    
car_sales_missing["Engine Size"] = engine_size
car_sales_missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats  Engine Size
# 0     Honda  White        35431.0    4.0  15323.0      5     4.283440
# 1       BMW   Blue       192714.0    5.0  19943.0      5     1.638808
# 2     Honda  White        84714.0    4.0  28343.0      5     2.532298
# 3    Toyota  White       154365.0    4.0  13434.0      5     3.030468
# 4    Nissan   Blue       181577.0    3.0  14043.0      5     3.880476
# ..      ...    ...            ...    ...      ...    ...          ...
# 994     BMW   Blue       163322.0    3.0  31666.0      5     3.987880
# 995  Toyota  Black        35820.0    4.0  32042.0      5     3.705326
# 997  Nissan   Blue        66604.0    4.0  31570.0      5     4.397453
# 998   Honda  White       215883.0    4.0   4001.0      5     3.445266
# 999  Toyota   Blue       248360.0    4.0  12732.0      5     4.004094
#
# [815 rows x 7 columns]

# %%
# Create a column which represents the price of a car per kilometer
# Then view the DataFrame
car_sales_missing["Price Per KM"] = car_sales_missing["Price"]/car_sales_missing["Odometer (KM)"]
car_sales_missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats  Engine Size  \
# 0     Honda  White        35431.0    4.0  15323.0      5     4.283440
# 1       BMW   Blue       192714.0    5.0  19943.0      5     1.638808
# 2     Honda  White        84714.0    4.0  28343.0      5     2.532298
# 3    Toyota  White       154365.0    4.0  13434.0      5     3.030468
# 4    Nissan   Blue       181577.0    3.0  14043.0      5     3.880476
# ..      ...    ...            ...    ...      ...    ...          ...
# 994     BMW   Blue       163322.0    3.0  31666.0      5     3.987880
# 995  Toyota  Black        35820.0    4.0  32042.0      5     3.705326
# 997  Nissan   Blue        66604.0    4.0  31570.0      5     4.397453
# 998   Honda  White       215883.0    4.0   4001.0      5     3.445266
# 999  Toyota   Blue       248360.0    4.0  12732.0      5     4.004094
#
#      Price Per KM
# 0        0.432474
# 1        0.103485
# 2        0.334573
# 3        0.087027
# 4        0.077339
# ..            ...
# 994      0.193887
# 995      0.894528
# 997      0.473996
# 998      0.018533
# 999      0.051264
#
# [815 rows x 8 columns]

# %%
# Remove the last column you added using .drop()
car_sales_missing.drop(["Price Per KM"], axis = 1)
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats  Engine Size
# 0     Honda  White        35431.0    4.0  15323.0      5     4.283440
# 1       BMW   Blue       192714.0    5.0  19943.0      5     1.638808
# 2     Honda  White        84714.0    4.0  28343.0      5     2.532298
# 3    Toyota  White       154365.0    4.0  13434.0      5     3.030468
# 4    Nissan   Blue       181577.0    3.0  14043.0      5     3.880476
# ..      ...    ...            ...    ...      ...    ...          ...
# 994     BMW   Blue       163322.0    3.0  31666.0      5     3.987880
# 995  Toyota  Black        35820.0    4.0  32042.0      5     3.705326
# 997  Nissan   Blue        66604.0    4.0  31570.0      5     4.397453
# 998   Honda  White       215883.0    4.0   4001.0      5     3.445266
# 999  Toyota   Blue       248360.0    4.0  12732.0      5     4.004094
#
# [815 rows x 7 columns]

# %%
# Shuffle the DataFrame using sample() with the frac parameter set to 1
# Save the the shuffled DataFrame to a new variable
car_sales_missing_shuffled = car_sales_missing.sample(frac = 1)
car_sales_missing_shuffled
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats  Engine Size  \
# 390  Toyota  White  131253.237895    4.0   8500.0      5     3.399042
# 182  Toyota   Blue   89501.000000    4.0  12218.0      5     2.758791
# 63    Honda  Green   47019.000000    4.0  20370.0      5     2.717830
# 262   Honda  Green   46085.000000    4.0  29681.0      5     3.391104
# 205  Toyota   Blue  154576.000000    4.0  12553.0      5     2.691287
# ..      ...    ...            ...    ...      ...    ...          ...
# 710  Nissan  White  177272.000000    4.0  18248.0      5     3.293490
# 470  Toyota  Green  119394.000000    4.0  11773.0      5     1.645136
# 471  Nissan  Black  178899.000000    4.0   5222.0      5     2.762976
# 908  Nissan  White  131253.237895    3.0  15861.0      5     3.321415
# 981  Toyota  White  129454.000000    4.0   6446.0      5     1.700877
#
#      Price Per KM
# 390      0.064760
# 182      0.136512
# 63       0.433229
# 262      0.644049
# 205      0.081209
# ..            ...
# 710      0.102938
# 470      0.098606
# 471      0.029190
# 908      0.120843
# 981      0.049794
#
# [815 rows x 8 columns]

# %% [markdown]
# Notice how the index numbers get moved around. The [`sample()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html) function is a great way to get random samples from your DataFrame. It's also another great way to shuffle the rows by setting `frac=1`.

# %%
# Reset the indexes of the shuffled DataFrame
car_sales_missing.reset_index()
# Out:
#      index    Make Colour  Odometer (KM)  Doors    Price  Seats  Engine Size  \
# 0        0   Honda  White        35431.0    4.0  15323.0      5     4.283440
# 1        1     BMW   Blue       192714.0    5.0  19943.0      5     1.638808
# 2        2   Honda  White        84714.0    4.0  28343.0      5     2.532298
# 3        3  Toyota  White       154365.0    4.0  13434.0      5     3.030468
# 4        4  Nissan   Blue       181577.0    3.0  14043.0      5     3.880476
# ..     ...     ...    ...            ...    ...      ...    ...          ...
# 810    994     BMW   Blue       163322.0    3.0  31666.0      5     3.987880
# 811    995  Toyota  Black        35820.0    4.0  32042.0      5     3.705326
# 812    997  Nissan   Blue        66604.0    4.0  31570.0      5     4.397453
# 813    998   Honda  White       215883.0    4.0   4001.0      5     3.445266
# 814    999  Toyota   Blue       248360.0    4.0  12732.0      5     4.004094
#
#      Price Per KM
# 0        0.432474
# 1        0.103485
# 2        0.334573
# 3        0.087027
# 4        0.077339
# ..            ...
# 810      0.193887
# 811      0.894528
# 812      0.473996
# 813      0.018533
# 814      0.051264
#
# [815 rows x 9 columns]

# %% [markdown]
# Notice the index numbers have been changed to have order (start from 0).

# %%
# Change the Odometer values from kilometers to miles using a Lambda function
# Then view the DataFrame
car_sales_missing["Odometer (KM)"] = car_sales_missing["Odometer (KM)"].apply(lambda x: x * 0.62)
car_sales_missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats  Engine Size  \
# 0     Honda  White     13619.6764    4.0  15323.0      5     4.283440
# 1       BMW   Blue     74079.2616    5.0  19943.0      5     1.638808
# 2     Honda  White     32564.0616    4.0  28343.0      5     2.532298
# 3    Toyota  White     59337.9060    4.0  13434.0      5     3.030468
# 4    Nissan   Blue     69798.1988    3.0  14043.0      5     3.880476
# ..      ...    ...            ...    ...      ...    ...          ...
# 994     BMW   Blue     62780.9768    3.0  31666.0      5     3.987880
# 995  Toyota  Black     13769.2080    4.0  32042.0      5     3.705326
# 997  Nissan   Blue     25602.5776    4.0  31570.0      5     4.397453
# 998   Honda  White     82985.4252    4.0   4001.0      5     3.445266
# 999  Toyota   Blue     95469.5840    4.0  12732.0      5     4.004094
#
#      Price Per KM
# 0        0.432474
# 1        0.103485
# 2        0.334573
# 3        0.087027
# 4        0.077339
# ..            ...
# 994      0.193887
# 995      0.894528
# 997      0.473996
# 998      0.018533
# 999      0.051264
#
# [815 rows x 8 columns]

# %%
# Change the title of the Odometer (KM) to represent miles instead of kilometers
car_sales_missing.rename(columns={"Odometer (KM)" : "Odometer (miles)"})
# Out:
#        Make Colour  Odometer (miles)  Doors    Price  Seats  Engine Size  \
# 0     Honda  White        13619.6764    4.0  15323.0      5     4.283440
# 1       BMW   Blue        74079.2616    5.0  19943.0      5     1.638808
# 2     Honda  White        32564.0616    4.0  28343.0      5     2.532298
# 3    Toyota  White        59337.9060    4.0  13434.0      5     3.030468
# 4    Nissan   Blue        69798.1988    3.0  14043.0      5     3.880476
# ..      ...    ...               ...    ...      ...    ...          ...
# 994     BMW   Blue        62780.9768    3.0  31666.0      5     3.987880
# 995  Toyota  Black        13769.2080    4.0  32042.0      5     3.705326
# 997  Nissan   Blue        25602.5776    4.0  31570.0      5     4.397453
# 998   Honda  White        82985.4252    4.0   4001.0      5     3.445266
# 999  Toyota   Blue        95469.5840    4.0  12732.0      5     4.004094
#
#      Price Per KM
# 0        0.432474
# 1        0.103485
# 2        0.334573
# 3        0.087027
# 4        0.077339
# ..            ...
# 994      0.193887
# 995      0.894528
# 997      0.473996
# 998      0.018533
# 999      0.051264
#
# [815 rows x 8 columns]

# %% [markdown]
# ## Extensions
#
# For more exercises, check out the pandas documentation, particularly the [10-minutes to pandas section](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html).
#
# One great exercise would be to retype out the entire section into a Jupyter Notebook of your own.
#
# Get hands-on with the code and see what it does.
#
# The next place you should check out are the [top questions and answers on Stack Overflow for pandas](https://stackoverflow.com/questions/tagged/pandas?sort=MostVotes&edited=true). Often, these contain some of the most useful and common pandas functions. Be sure to play around with the different filters!
#
# Finally, always remember, the best way to learn something new to is try it. Make mistakes. Ask questions, get things wrong, take note of the things you do most often. And don't worry if you keep making the same mistake, pandas has many ways to do the same thing and is a big library. So it'll likely take a while before you get the hang of it.
